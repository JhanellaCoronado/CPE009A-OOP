# %% [markdown]
# <a href="https://colab.research.google.com/github/JhanellaCoronado/CPE009A-OOP/blob/main/Prelim%20Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prelim Quiz

# %%
n=20
totalnumbers=n
sum=0

while n>=0:
  sum+=n
  n-=1

average=sum/totalnumbers

print("Sum of is:",sum)
print("Average of is:",average)
# Out:
# Sum of is: 210
# Average of is: 10.5

# %% [markdown]
# Flowchart
#
# https://lucid.app/documents/view/2ff171c5-aa87-499c-8322-4f8d44c922fe
#
# ![Prelim quiz.jpeg](data:image/jpeg;base64,...)
